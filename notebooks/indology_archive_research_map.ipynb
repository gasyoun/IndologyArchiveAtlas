# %% [markdown]
# # INDOLOGY Archive Research Map
#
# This notebook runs the metadata-first pipeline for the INDOLOGY archive. Use a small year range for validation, then expand to the full 1990-2026 archive.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT))
ROOT

# %%
from indology_archive_research.scrape import harvest_archive
from indology_archive_research.analysis import save_tables, plot_figures
from indology_archive_research.validate import write_report

# Start with a small slice; set start_year=1990 for the full archive.
harvest_archive(ROOT, start_year=2026, end_year=2026, insecure=True, delay=0.0, retries=3)
tables = save_tables(ROOT)
plot_figures(ROOT, tables)
write_report(ROOT)

# %%
tables['messages'].head()

# %%
tables['topic_year_counts'].sort_values(['year', 'message_count'], ascending=[True, False]).head(20)
